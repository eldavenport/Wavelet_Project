# %% [markdown]
# #1. Setup

# %%
import numpy as np
import pandas as pd


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision
from torchvision import datasets, models, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision.transforms as transforms

from torchsummary import summary

import matplotlib.pyplot as plt
import cv2

import time
import os

from PIL import Image

from tqdm import tqdm
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from skimage.transform import rescale, resize, downscale_local_mean
from skimage.io import imread, imsave
from skimage.transform import rotate
from skimage.util import random_noise
from skimage.filters import gaussian
from scipy import ndimage


torch.manual_seed(1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install split_folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split_folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %% [markdown]
# #2. Data Setup

# %%
cd /content/drive/MyDrive/data/
# Out:
# /content/drive/MyDrive/Wavelets Project/data

# %%
# !unzip '/content/drive/My Drive/data/Wavelet_packet_test_db2.zip' -d '/root/datasets'
# Out:
# Archive:  /content/drive/My Drive/data/Wavelet_packet_test_db2.zip
#    creating: /root/datasets/Wavelet_packet_test_db2/
#    creating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2921.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1916.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_275.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1558.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1271.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2614.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_326.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_3033.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1235.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2921.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2204.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2479.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2507.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2053.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_3485.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2937.png
#  extracting: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1152.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1298.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_382.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_368.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2903.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1235.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1492.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_949.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2887.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2973.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_3110.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_949.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2793.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1862.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1816.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2793.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_588.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_3423.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_3423.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_730.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_3402.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_477.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_3402.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1916.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1765.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_242.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_3006.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_3407.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_574.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1569.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_382.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1346.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_735.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2650.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2706.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1455.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_431.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1816.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_3006.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_3093.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1492.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_473.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1617.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1765.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2903.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2815.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_431.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_3045.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1205.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_3045.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2815.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_3093.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_199.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2590.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_3409.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_3488.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2188.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2706.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1455.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_500.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_3409.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2937.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_3407.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_3033.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1620.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_806.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_473.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2204.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1321.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2053.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_477.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1073.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_574.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1073.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_575.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1862.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1298.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_730.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2650.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1271.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_952.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_952.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_3485.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_3208.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_7.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2479.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_199.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2693.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1346.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_500.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2973.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2981.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_242.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1617.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2614.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1321.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_3488.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_806.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2981.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_575.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_7.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_3208.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1558.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1502.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2208.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2208.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1620.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_735.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1569.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_275.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_712.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_2590.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1502.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_368.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2887.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_3110.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_588.png
#  extracting: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_1152.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_712.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2188.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/flipped_n02085620_326.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2507.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_2693.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Chihuahua/n02085620_1205.png
#    creating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_124.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_10.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_135.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_199.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_100.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_110.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_162.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_116.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_18.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_122.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_104.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_129.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_164.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_147.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_166.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_175.png
#  extracting: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_137.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_157.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_175.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_11.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_123.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_109.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_189.png
#  extracting: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_114.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_152.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_173.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_117.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_105.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_176.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_171.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_154.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_194.png
#  extracting: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_127.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_190.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_145.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_140.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_125.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_122.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_181.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_195.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_142.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_140.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_106.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_14.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_183.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_165.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_185.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_132.png
#  extracting: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_127.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_124.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_154.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_133.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_126.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_113.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_146.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_171.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_146.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_101.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_130.png
#  extracting: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_112.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_199.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_158.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_131.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_109.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_185.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_178.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_125.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_10.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_159.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_116.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_13.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_190.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_181.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_172.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_135.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_19.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_128.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_163.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_11.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_106.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_168.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_16.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_107.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_103.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_164.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_153.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_16.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_186.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_177.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_119.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_158.png
#  extracting: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_114.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_153.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_180.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_174.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_187.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_108.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_165.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_156.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_160.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_128.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_189.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_152.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_132.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_191.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_168.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_170.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_118.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_105.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_134.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_155.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_193.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_118.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_126.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_14.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_145.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_130.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_13.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_139.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_144.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_139.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_12.png
#  extracting: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_120.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_178.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_143.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_193.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_142.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_196.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_157.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_192.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_160.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_196.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_161.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_141.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_121.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_111.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_115.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_108.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_129.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_173.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_100.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu_123.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/shiba_inu_166.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/Shiba Inu/flipped_shiba_inu
png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_3640.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_1839.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_4860.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_7608.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_57.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_10204.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_311.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_11207.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_1114.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_5813.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_8258.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_2603.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_6521.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_2118.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_328.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_8604.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_311.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_2279.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_7806.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_2514.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_6462.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_5669.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_5458.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_1137.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_142.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_5306.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_4133.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_3266.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_2681.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_4066.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_1895.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_3202.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_1188.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_4372.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_9457.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_8696.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_4500.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_2326.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_720.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_9530.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_12139.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_2380.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_1752.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_3202.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_9899.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_5319.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_1119.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_12904.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_3913.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_4901.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_4603.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_11327.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_2946.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_6521.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_12618.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_3369.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_971.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_2681.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_3557.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_1911.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_12139.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_5087.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_4372.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_2570.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_6462.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_110.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_3266.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_1343.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_656.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_10204.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_3702.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_350.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_38.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_553.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_481.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_3369.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_1788.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_895.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_653.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_2835.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_38.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_2899.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_1465.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_3665.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_5087.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_4214.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_9202.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_3153.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_3346.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_3300.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_9399.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_1871.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_623.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_644.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_3083.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_5319.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_198.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_4133.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_2603.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_4474.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_3544.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_977.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_11220.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_11653.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_3520.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_57.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_6008.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_2980.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_2166.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/flipped_n02108915_2326.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_4474.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_3640.png
#   inflating: /root/datasets/Wavelet_packet_test_db2/French Bulldog/n02108915_759.png

# %%
# define training and test data directories
main_dir = '/root/datasets/Wavelet_packet_test_db2'
split_data_dir = '/root/split_dataset'

classes = ['Beagle', 'Chihuahua', 'French Bulldog', 'German Shepherd', 'Golden Retriever', 'Labrador Retriever', 'Poodle', 'Samoyed', 'Schnauzer', 'Shiba Inu', 'West Highland White Terrier']

# %%
import splitfolders

splitfolders.ratio(main_dir, output=split_data_dir, seed=1337, ratio=(.6, 0.2 , 0.2))


train_dir = os.path.join(split_data_dir, 'train')
val_dir = os.path.join(split_data_dir, 'val')
test_dir = os.path.join(split_data_dir, 'test')
# Out:
# Copying files: 3132 files [00:01, 1886.41 files/s]

# %%
# print(os.path.exists(split_data_dir + '/test/.ipynb_checkpoints'))
# os.rmdir(split_data_dir + '/test/.ipynb_checkpoints')
# print(os.listdir(split_data_dir + '/test'))

# print(os.path.exists(split_data_dir + '/train/.ipynb_checkpoints'))
# os.rmdir(split_data_dir + '/train/.ipynb_checkpoints')
# print(os.listdir(split_data_dir + '/train'))

# print(os.path.exists(split_data_dir + '/val/.ipynb_checkpoints'))
# os.rmdir(split_data_dir + '/val/.ipynb_checkpoints')
# print(os.listdir(split_data_dir + '/val'))

# %%
# load and transform data using ImageFolder

# resize all images to 256 x 256, crop to 224 x 224, transform to tensor, normalize
data_transform = transforms.Compose([transforms.Resize(256)                    
                                     ,transforms.CenterCrop(224)                #[3]
                                     ,transforms.ToTensor()                     #[4]
                                     ,transforms.Normalize(                      #[5]
                                     mean=[0.485, 0.456, 0.406],                #[6]
                                     std=[0.229, 0.224, 0.225]                  #[7]
                                     )
                                    ])
                                   
train_data = datasets.ImageFolder(train_dir, transform=data_transform)
val_data = datasets.ImageFolder(val_dir, transform=data_transform)
test_data = datasets.ImageFolder(test_dir, transform=data_transform)

# print out some data stats
print('Number of training images: ', len(train_data))
print('Number of validation images: ', len(val_data))
print('Number of test images: ', len(test_data))
# Out:
# Number of training images:  1876
# Number of validation images:  624
# Number of test images:  632

# %%
# define dataloader parameters
batch_size = 32
num_workers = 0

# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
                                           num_workers=num_workers, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, 
                                          num_workers=num_workers, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
                                          num_workers=num_workers, shuffle=True)

# %%
# Visualize some sample data

# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display
# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(30, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    plt.imshow(np.transpose(images[idx], (1, 2, 0)))
    ax.set_title(classes[labels[idx]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-844dada020e2> in <module>
#       3 # obtain one batch of training images
#       4 dataiter = iter(train_loader)
# ----> 5 images, labels = dataiter.next()
#       6 images = images.numpy() # convert images to numpy for display
#       7 # plot the images in the batch, along with the corresponding labels
#
# AttributeError: '_SingleProcessDataLoaderIter' object has no attribute 'next'

# %% [markdown]
# #3. Transfer Learning

# %%
import torchvision.models
alexnet = torchvision.models.alexnet(pretrained=True)

# %%
# img = ... a PyTorch tensor with shape [N,3,224,224] containing hand images ...
features = alexnet.features

# %% [markdown]
# #4. Classification Model

# %%
 class AlexClassifier(nn.Module):
    def __init__(self):
        super(AlexClassifier, self).__init__()
        self.fc1 = nn.Linear(256 * 6 * 6,  4069)
        self.fc2 = nn.Linear(4069,  1000)
        self.fc3 = nn.Linear(1000, 11)

    def forward(self, x):
        x = x.view(-1, 256 * 6 * 6) #flatten feature data
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# #5. Training Setup

# %%
def evaluate(model, loader, criterion):

    total_loss = 0
    total_correct = 0
    total_epoch = 0
    i = 0

    for imgs, labels in iter(loader):
          
        i += 1     

        if use_cuda and torch.cuda.is_available():

          imgs = imgs.cuda()
          labels = labels.cuda()

        output = model(features(imgs))
        pred = output.max(1, keepdim=True)[1]
        loss = criterion(output, labels)
        
        total_correct += pred.eq(labels.view_as(pred)).sum().item()
        total_loss += loss.item()
        total_epoch += len(labels)

    err =  1 - (total_correct/ total_epoch)
    loss = total_loss / (i + 1)
    return err, loss

# %%
def get_accuracy(model, loader):
    correct = 0
    total = 0
    
    for imgs, labels in loader:
        
        if use_cuda and torch.cuda.is_available():
          
          imgs = imgs.cuda()
          labels = labels.cuda()
        
        output = model(features(imgs))
        pred = output.max(1, keepdim=True)[1] # get the index of the max logit 

        correct += pred.eq(labels.view_as(pred)).sum().item()
        # print('correct: ', correct)
        total += imgs.shape[0]
        # print('incorrect: ', total - correct)
    return correct / total

# %%
def train(model, train_loader, val_loader, batch_size=20, learning_rate = 0.001,  num_epochs=1):


  torch.manual_seed(1000)

  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  iters, train_error, val_error, train_loss, val_loss = [], [], [], [], []

  # training

  n = 0 # the number of iterations

  start_time = time.time()

  for epoch in range(num_epochs):

      mini_b= 0
      mini_batch_correct = 0
      Mini_batch_total = 0
      
      for imgs, labels in iter(train_loader):       
          
      #To Enable GPU Usage
        if use_cuda and torch.cuda.is_available():

          imgs = imgs.cuda()
          labels = labels.cuda()
        
        out = model(features(imgs))             # forward pass
        loss = criterion(out, labels) # compute the total loss
        loss.backward()               # backward pass (compute parameter updates)
        optimizer.step()              # make the updates for each parameter
        optimizer.zero_grad()         # a clean up step for PyTorch

        pred = out.max(1, keepdim=True)[1]
        mini_batch_correct = pred.eq(labels.view_as(pred)).sum().item()
        Mini_batch_total = imgs.shape[0]

        train_error.append(1 - (mini_batch_correct / Mini_batch_total))
        train_loss.append(loss.item())
        

        iters.append(n)
        val_err, val_los = evaluate(model, val_loader, criterion)
        val_error.append(val_err)  # compute validation accuracy
        val_loss.append(val_los)  # compute validation accuracy

        n += 1
        mini_b += 1

      print ("Epoch %d Finished. " % epoch ,"Time per Epoch: % 6.2f s "% ((time.time()-start_time) / (epoch +1)))


  end_time = time.time()
  # plotting
  fig, (ax1, ax2) = plt.subplots(1, 2)

  ax1.set_title("Error")
  ax1.plot(iters, train_error, label="Training")
  ax1.plot(iters, val_error, label="Validation") 
  ax1.set_xlabel("Iterations")
  ax1.set_ylabel("Error")
  ax1.legend(loc='best')

  ax2.set_title("Loss")
  ax2.plot(iters, train_loss, label="Training")
  ax2.plot(iters, val_loss, label="Validation")    
  ax2.set_xlabel("Iterations")
  ax2.set_ylabel("Loss")
  ax2.legend(loc='best')
  
  fig.show()


  train_error.append(1 - get_accuracy(model, train_loader))

  print("Final Training Error:   {}\tFinal Training Accuracy:   {}".format(train_error[-1],1 - train_error[-1]))
  print("Final Validation Error: {}\tFinal Validation Accuracy: {}".format(val_error[-1]  ,1 - val_error[-1]  ))
  print ("Total time:  % 6.2f s  Time per Epoch: % 6.2f s " % ( (end_time-start_time), ((end_time-start_time) / num_epochs) ))

# %% [markdown]
# #6. Test Setup

# %%
def get_test_accuracy(model, data):
    correct = 0
    total = 0

    loader = torch.utils.data.DataLoader(data, batch_size=batch_size, 
                                           num_workers=num_workers, shuffle=True)

    # model.eval() #*********#
    
    for imgs, labels in loader:
        
        if use_cuda and torch.cuda.is_available():
          
          imgs = imgs.cuda()
          labels = labels.cuda()
        
        output = model(imgs)
        
        pred = output.max(1, keepdim=True)[1] # get the index of the max logit
        
        image = images[0]
        # place the colour channel at the end, instead of at the beginning
        img = np.transpose(image, [1,2,0])
        # normalize pixel intensity values to [0, 1]
        img = img / 2 + 0.5
        plt.subplot(3, 5, 1)
        plt.axis('off')
        plt.imshow(img)
        
        correct += pred.eq(labels.view_as(pred)).sum().item()
        print("predict", output)
        total += imgs.shape[0]
    return correct / total

# %%
from torch.utils.data.sampler import SubsetRandomSampler

def get_random_images(data_dir, num):

    data_transform = transforms.Compose([transforms.Resize(256),
                                         transforms.CenterCrop(224),
                                         transforms.ToTensor()
                                        #  ,transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
                                         ])

    data = datasets.ImageFolder(data_dir, transform=data_transform)
    classes = data.classes
    # classes.remove('.ipynb_checkpoints')

    indices = list(range(len(data)))
    np.random.shuffle(indices)
    idx = indices[:num]
    sampler = SubsetRandomSampler(idx)
    loader = torch.utils.data.DataLoader(data, sampler=sampler, batch_size=num)

    return loader

# %% [markdown]
# #7. Training

# %%
use_cuda = True
features = alexnet.features
alex = AlexClassifier()

if use_cuda and torch.cuda.is_available():
  alex.cuda()
  features.cuda()
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')

train(alex, train_loader, val_loader, batch_size=32, num_epochs=10, learning_rate=0.0001)

# %% [markdown]
# #8. Test

# %%
test_accuracy  = get_accuracy(alex, test_loader)

print('The test Accuracy is:',test_accuracy )

# %%
loader = get_random_images(test_dir, 10)
dataiter = iter(loader)
images, labels = dataiter.next()

if use_cuda and torch.cuda.is_available():

    images = images.cuda()
    labels = labels.cuda()

outputs = alex(features(images))

# %%
fig=plt.figure(figsize=(120,100))
accuracy = 0
for i in list(range(0, 10)):
    pred  = loader.dataset.classes[outputs[i].max(-1, keepdim=True)[1]]
    img =  images[i].cpu()
    lbl = loader.dataset.classes[labels[i]]

    if pred == lbl:
        accuracy += 1

    ax = fig.add_subplot(5, 50/2, i+1, xticks=[], yticks=[])
    plt.imshow(np.transpose(img, (1, 2, 0)))
    title = 'True Label: ' + lbl + '\n Prediction Label: ' + pred
    ax.set_title(title)
    
plt.show()
print('Accuracy: ', accuracy)
